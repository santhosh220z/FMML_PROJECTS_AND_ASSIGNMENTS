# %% [markdown]
# <a href="https://colab.research.google.com/github/santhosh220z/FMML_PROJECTS_AND_ASSIGNMENTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-13 14:45:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   194MB/s    in 0.4s
#
# 2024-05-13 14:45:08 (194 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 2500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2963 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 150  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 11  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21604   1110.4531v4  We propose a method called ideal regression fo...  stat
# 17325  1710.03203v2  The surge of social media use brings huge dema...    cs
# 11233  1506.00745v2  There are three principle paradigms of statist...  stat
# 36347   1212.2458v1  Inferences in directed acyclic graphs associat...    cs
# 876     1412.6544v6  Training neural networks involves solving larg...    cs
# ...             ...                                                ...   ...
# 7374   1712.02162v2  Deep learning (DL), a new-generation artificia...  stat
# 8322   1511.04397v5  In this paper, we propose a new text recogniti...    cs
# 11256  1506.05855v4  A central problem in statistics is model selec...  stat
# 5360    1304.5678v1  Support vector machines (SVMs) rely on the inh...    cs
# 38927   1402.1801v1  Ultra low radiation dose in X-ray Computed Tom...  stat
#
#                                                    title  year  \
# 21604        Regression for sets of polynomial equations  2011
# 17325  Deep Learning Paradigm with Transformed Monoli...  2017
# 11233  An objective prior that unifies objective Baye...  2015
# 36347  Inference in Polytrees with Sets of Probabilities  2012
# 876    Qualitatively characterizing neural network op...  2014
# ...                                                  ...   ...
# 7374   A trans-disciplinary review of deep learning r...  2017
# 8322   Similarity-based Text Recognition by Deeply Su...  2015
# 11256  Information-based inference for singular model...  2015
# 5360   Analytic Feature Selection for Support Vector ...  2013
# 38927  Efficient Low Dose X-ray CT Reconstruction thr...  2014
#
#                                                 keywords
# 21604  [regression, approximating, arbitrary, polynom...
# 17325  [multilingual, sentiment, unveiling, differenc...
# 11233  [principle, paradigms, statistical, inference,...
# 36347  [inferences, associated, probability, probabil...
# 876    [optimization, extremely, difficult, obstacles...
# ...                                                  ...
# 7374   [generation, artificial, resources, scientists...
# 8322   [recognition, measuring, similarity, predictin...
# 11256  [statistics, selection, competing, stochastic,...
# 5360   [excellent, candidate, development, selection,...
# 38927  [radiation, tomography, important, objective, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21604    [regression, approximating, arbitrary, polynom...
# 17325    [multilingual, sentiment, unveiling, differenc...
# 11233    [principle, paradigms, statistical, inference,...
# 36347    [inferences, associated, probability, probabil...
# 876      [optimization, extremely, difficult, obstacles...
#                                ...
# 3720     [information, bottleneck, clustering, distribu...
# 30316    [interpretation, recognized, observers, approa...
# 5877     [approximation, regression, approximation, con...
# 14627    [describes, interdisciplinary, linguistics, tr...
# 7809     [adaptation, sufficiently, observations, trans...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8774 words.
# Out of those 4535 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8ace838b-93c0-4750-8e34-07c6971aa052" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ace838b-93c0-4750-8e34-07c6971aa052")) {                    Plotly.newPlot(                        "8ace838b-93c0-4750-8e34-07c6971aa052",                        [{"x":["formulate","numerical","algebraic","stationary","consistent","simulations","approaches","optimization","separation","polynomial","regression","particular","techniques","equations","resorting","approximate","approximating","described","demonstrate","computational","arbitrary","estimator","traditional","especially","multilingual","languages","effective","difference","unveiling","conditioned","different","differences","experimental","monolingual","outperforms","embeddings","transformed","parameter","separately","translating","sentiment","classification","translation","embedding","applicable","performance","inference","asymptotic","generically","distinguishable","analogous","definition","equivalent","principle","statistical","understood","interpretations","suppressing","objective","criterion","complexity","maximally","mechanism","predictive","paradigms","regularization","uninformative","including","perspective","information","predictivity","weighting","frequentist","uniformly","probability","improvement","algorithm","substantial","intervals","probabilities","associated","procedures","improvements","inferences","algorithms","solutions","direction","polytrees","magnitude","collection","stochastic","significant","extremely","introduce","technique","overcoming","initialization","unsupervised","negligible","pretraining","qualitatively","characterizing","difficult","encounter","motivating","obstacles","representations","recognizing","expressive","expression","collaborative","representation","unavailable","components","incorporating","recognition","hierarchical","competitive","challenging","benchmark","dedicated","clustering","identification","annotated","attention","selection","proposals","representing","respectively","appropriate","coordinates","localization","completely","iteration","classifiers","discovery","addresses","similarity","supervised","perceptual","achieving","searching","comparable","naturally","percentage","annotations","iterative","probabilistic","committee","measuring","distribution","investigates","contribute","empirical","parameters","unlabeled","reduction","efficiency","extending","informative","disagreement","informativeness","excellent","sufficient","annotation","expensive","processing","interpretability","processes","particularly","prediction","variational","tractably","overestimate","conventional","modelling","interpretable","encountered","circumstances","predicted","stability","adversely","demonstrates","sensitivity","neighbors","validation","attribute","theoretical","designated","relationship","coalescent","nonparametric","accomplish","uncertainty","maximized","arbitrarily","impulsive","successfully","filtering","robustness"],"y":[58,79,19,27,77,36,463,303,25,66,118,240,384,25,6,99,15,61,524,274,67,24,169,102,20,95,239,53,2,24,694,35,371,5,277,74,38,127,24,15,45,510,107,87,51,897,205,13,3,2,10,39,60,58,151,29,11,2,155,40,246,5,115,53,17,75,1,237,60,692,0,13,2,13,178,136,794,41,20,64,94,45,109,15,615,170,65,2,52,70,131,252,53,335,217,7,28,134,11,3,22,25,144,5,6,5,230,40,37,54,38,372,10,98,53,373,108,129,275,186,16,138,93,62,182,166,33,70,90,68,17,66,32,42,118,68,55,133,201,29,76,29,104,71,14,64,84,164,8,35,200,20,28,148,251,52,93,168,27,38,5,7,28,68,60,64,284,18,103,71,235,45,0,1,109,47,36,16,5,49,40,4,57,41,27,48,30,155,9,67,1,12,17,94,3,13,4,84,71,111],"type":"bar"},{"x":["formulate","numerical","algebraic","stationary","consistent","simulations","ap ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4535,), (4535, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8275

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Using</span> <span style='background-color:rgba(0, 255, 0, 0.5272727272727271);'>Qualitative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Relationships</span> <span style=''>for</span> <span style=''>Bounding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style='background-color:rgba(255, 0, 0, 0.3818181818181817);'>Distributions</span> <br/><br/><span style=''>We</span> <span style=''>exploit</span> <span style='background-color:rgba(0, 255, 0, 0.5272727272727271);'>qualitative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>among</span> <span style='background-color:rgba(255, 0, 0, 0.34653465346534645);'>variables</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>bounds</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3818181818181817);'>distributions</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>Using</span> <span style=''>the</span> <span style=''>signs</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5272727272727271);'>qualitative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationships</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style='background-color:rgba(0, 255, 0, 0.8064516129032259);'>abstraction</span> <span style='background-color:rgba(0, 255, 0, 0.5106382978723403);'>operations</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guaranteed</span> <span style=''>to</span> <span style=''>bound</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3818181818181817);'>distributions</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>the</span> <span style=''>desired</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluating</span> <span style='background-color:rgba(0, 255, 0, 0.625);'>incrementally</span> <span style=''>improved</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>networks</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>obtains</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>monotonically</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>tightening</span> <span style=''>bounds</span> <span style=''>that</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3818181818181817);'>distributions</span> <span style=''>For</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>supermodular</span> <span style=''>utility</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>tightening</span> <span style=''>bounds</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>monotonically</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8181818181818181);'>admissible</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.3142857142857144);'>alternatives</span> <span style=''>as</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Backpropagation</span> <span style=''>for</span> <span style=''>Scalable</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Bayesian</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>Large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilayer</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>trained</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>backpropagation</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>achieved</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>results</span> <span style=''>in</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>range</span> <span style=''>of</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>using</span> <span style=''>backprop</span> <span style=''>for</span> <span style=''>neural</span> <span style=''>net</span> <span style=''>learning</span> <span style=''>still</span> <span style=''>has</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>disadvantages</span> <span style=''>eg</span> <span style=''>having</span> <span style=''>to</span> <span style=''>tune</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>to</span> <span style=''>the</span> <span style=''>data</span> <span style=''>lack</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>calibrated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>and</span> <span style=''>a</span> <span style=''>tendency</span> <span style=''>to</span> <span style=''>overfit</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>learning</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>does</span> <span style=''>not</span> <span style=''>have</span> <span style=''>these</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>existing</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>lack</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scalability</span> <span style=''>to</span> <span style=''>large</span> <span style=''>dataset</span> <span style=''>and</span> <span style=''>network</span> <span style=''>sizes</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>scalable</span> <span style=''>method</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>Bayesian</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>backpropagation</span> <span style=''>(PBP)</span> <span style=''>Similar</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>backpropagation</span> <span style=''>PBP</span> <span style=''>works</span> <span style=''>by</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Sparse</span> <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.5123966942148761);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>training</span> <span style=''>data</span> <span style=''>to</span> <span style=''>induce</span> <span style=''>sparsity</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.5123966942148761);'>regression</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.33936651583710403);'>estimates</span> <span style=''>an</span> <span style=''>inducing</span> <span style=''>set</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5428571428571428);'>hyperparameters</span> <span style=''>using</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>either</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.5042735042735043);'>likelihood</span> <span style=''>or</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.6153846153846154);'>variational</span> <span style=''>free</span> <span style=''>energy</span> <span style=''>The</span> <span style=''>space</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>are</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>training</span> <span style=''>set</span> <span style=''>size</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.5123966942148761);'>regression</span> <span style=''>problems</span> <span style=''>on</span> <span style=''>discrete</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>domains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style='background-color:rgba(0, 255, 0, 0.37764350453172196);'>evaluation</span> <span style=''>shows</span> <span style=''>state</span> <span style=''>of</span> <span style=''>art</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>discrete</span> <span style=''>cases</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style=''>results</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>case</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Group</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Invariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stability</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Deformations</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Complexity</span> <span style=''>of</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>deep</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>to</span> <span style=''>groups</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformations</span> <span style=''>and</span> <span style=''>stable</span> <span style=''>to</span> <span style=''>the</span> <span style=''>action</span> <span style=''>of</span> <span style=''>diffeomorphisms</span> <span style=''>without</span> <span style=''>losing</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>This</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multilayer</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>kernel</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>by</span> <span style=''>studying</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>is</span> <span style=''>stable</span> <span style=''>and</span> <span style=''>that</span> <span style=''>models</span> <span style=''>from</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>space</span> <span style=''>such</span> <span style=''>as</span> <span style=''>a</span> <span style=''>large</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homogeneous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>may</span> <span style=''>enjoy</span> <span style=''>the</span> <span style=''>same</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>norm</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13287965616045846)
# 	processing (0.1017191977077364)
# 	segmentation (0.06697707736389685)
# 	architecture (0.08345272206303725)
# 	representation (0.1332378223495702)
# 	information (0.24785100286532952)
# 	different (0.248567335243553)
# 	detection (0.13001432664756446)
# 	convolutional (0.13359598853868196)
# 	recognition (0.13359598853868196)
#
# Some Statistics words are:
# 	variables (0.13545816733067728)
# 	theoretical (0.14940239043824702)
# 	stochastic (0.1409362549800797)
# 	statistical (0.15288844621513945)
# 	estimation (0.17380478087649404)
# 	distribution (0.18276892430278885)
# 	dimensional (0.1857569721115538)
# 	algorithm (0.4048804780876494)
# 	inference (0.19870517928286852)
# 	regression (0.18227091633466136)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9b072da6-0f19-418c-a1fb-935e5a0e205d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b072da6-0f19-418c-a1fb-935e5a0e205d")) {                    Plotly.newPlot(                        "9b072da6-0f19-418c-a1fb-935e5a0e205d",                        [{"x":["formulate","numerical","algebraic","stationary","consistent","simulations","approaches","optimization","separation","polynomial","regression","particular","techniques","equations","resorting","approximate","approximating","described","demonstrate","computational","arbitrary","estimator","traditional","especially","multilingual","languages","effective","difference","unveiling","conditioned","different","differences","experimental","monolingual","outperforms","embeddings","transformed","parameter","separately","translating","sentiment","classification","translation","embedding","applicable","performance","inference","asymptotic","generically","distinguishable","analogous","definition","equivalent","principle","statistical","understood","interpretations","suppressing","objective","criterion","complexity","maximally","mechanism","predictive","paradigms","regularization","uninformative","including","perspective","information","predictivity","weighting","frequentist","uniformly","probability","improvement","algorithm","substantial","intervals","probabilities","associated","procedures","improvements","inferences","algorithms","solutions","direction","polytrees","magnitude","collection","stochastic","significant","extremely","introduce","technique","overcoming","initialization","unsupervised","negligible","pretraining","qualitatively","characterizing","difficult","encounter","motivating","obstacles","representations","recognizing","expressive","expression","collaborative","representation","unavailable","components","incorporating","recognition","hierarchical","competitive","challenging","benchmark","dedicated","clustering","identification","annotated","attention","selection","proposals","representing","respectively","appropriate","coordinates","localization","completely","iteration","classifiers","discovery","addresses","similarity","supervised","perceptual","achieving","searching","comparable","naturally","percentage","annotations","iterative","probabilistic","committee","measuring","distribution","investigates","contribute","empirical","parameters","unlabeled","reduction","efficiency","extending","informative","disagreement","informativeness","excellent","sufficient","annotation","expensive","processing","interpretability","processes","particularly","prediction","variational","tractably","overestimate","conventional","modelling","interpretable","encountered","circumstances","predicted","stability","adversely","demonstrates","sensitivity","neighbors","validation","attribute","theoretical","designated","relationship","coalescent","nonparametric","accomplish","uncertainty","maximized","arbitrarily","impulsive","successfully","filtering","robustness","correntropy","minimizing","presented","variables","illustrative","considerable","conditions","estimation","distributed","centroids","nonlinear","theoretically","bootstrap","geometrically","proportional","gradually","clusterings","dimensionality","variations","multilayer","implicitly","randomization","correlation","utilising","correlated","transformation","distances","correlations","investigate","transformations","previously","functions","preserving","transforms","component","successful","interests","providing","exponential","individual","consisting","simulator","approximations","challenge","approximation","asymmetric","approximately","strategic","responsive","construct","important","addressing","individually","observations","clus ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	predictivity
# 	tractably
# 	correntropy
# 	straggler
# 	covariates
# 	exemplary
# 	parametrically
# 	commonplace
# 	regressive
# 	recasting
# 	operationalize
# 	capitalizing
# 	nonlinearly
# 	inferential
# 	blockwise
# 	extrapolate
# 	precautions
# 	byzantine
# 	quantiles
# 	textitnot
# Some words which never appear in Statistics papers:
# 	unveiling
# 	monolingual
# 	polytrees
# 	geometrically
# 	responsive
# 	avoidance
# 	morphosyntactic
# 	transliteration
# 	primitives
# 	ungrammatical
# 	repetitive
# 	unorganized
# 	occlusions
# 	reachability
# 	generations
# 	commercially
# 	syntactically
# 	syntactic
# 	manipulating
# 	envisioned

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081189339084887e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7708333333333334
